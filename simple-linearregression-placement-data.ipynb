# %% [markdown]
# <a href="https://www.kaggle.com/code/arjunkanthimath/simple-linearregression-placement-data?scriptVersionId=154306734" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **LINEAR REGRESSION MODEL TO PREDICT THE PACKAGE BASED ON CGPA**

# %%
import numpy as np # linear algebra
import pandas as pd #preprocessing 
import matplotlib.pyplot as plt #visualization
import sklearn as skt #ML model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/kaggle/input/cgpa-vs-package-in-lpa/placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %% [markdown]
# # **PLOTTING A GRAPH BETWEEN CGPA AND PACKAGE TO CHECK IF OUR DATA IS LINEAR**

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('PACKAGE [LPA]')
# Out:
# Text(0, 0.5, 'PACKAGE [LPA]')

# %% [markdown]
# # PREPROCESSING THE DATA

# %%
x = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
x.head()
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94

# %%
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %% [markdown]
# # **TRAINING OUR LINEAR REGRESSION MODEL**

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %% [markdown]
# # **PLOTTING THE GRAPH OF OUR TRAINED REGRESSION MODEL**

# %%
plt.scatter(df['cgpa'],df['package'],color='orange')
plt.plot(x_train,lr.predict(x_train),color='Red')
plt.xlabel('CGPA')
plt.ylabel('PACKAGE [LPA]')
# Out:
# Text(0, 0.5, 'PACKAGE [LPA]')

# %% [markdown]
# # **CALCULATING THE SLOPE AND INTERCEPT OF THE LINE**

# %%
# y = mx + b [equation of a line]
m = lr.coef_ # 0.55795197
b = lr.intercept_ # -0.8961119222429144
# y = 0.55795197 * x + (-0.8961119222429144)

# %% [markdown]
# # **CALCULATING THE ACCURACY OF THE MODEL**

# %%
r2_score = lr.score(x_test,y_test)
print(r2_score*100)
# Out:
# 78.0730147510384

# %% [markdown]
# # **ACCURACY = 78.0730147510384**
